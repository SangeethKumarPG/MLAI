# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !pwd
# Out:
# /content

# %%
#yolo train data='/content/drive/MyDrive/Colab Notebooks/household objects.v3i.yolov8/data.yaml' model=yolov8m.pt epochs=100 lr0=0.01
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 207MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
#yolo task=detect mode=predict model=/content/runs/detect/train11/weights/best.pt source="/content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels"
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/398 /content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels/115.jpg: 480x640 1 chocolate_drink, 1 coke, 1 sprite, 62.5ms
# image 2/398 /content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels/117.jpg: 480x640 1 chocolate_drink, 1 coke, 1 sprite, 7.3ms
# image 3/398 /content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels/123.jpg: 480x640 1 chocolate_drink, 1 coke, 1 sprite, 7.5ms
# image 4/398 /content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels/124.jpg: 480x640 1 chocolate_drink, 1 coke, 1 sprite, 16.3ms
# image 5/398 /content/drive/MyDrive/Colab Notebooks/household objects.v1i.yolov8/predict_labels/126.jpg: 480x640 1 basket, 1 chocolate_drink, 1 coke, 6.5ms
# ...

# %%
#yolo train model=yolov8n-seg.pt data=coco8-seg.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 362, in entrypoint
#     k, v = parse_key_value_pair(a)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 297, in parse_key_value_pair
#     assert v, f"missing '{k}' value"
# AssertionError: missing 'source' value
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 369, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ''}, e)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 205, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'source=' is not a valid YOLO argument. Similar arguments are i.e. ['source'].
#
# ...

# %%
# !yolo train data='/content/drive/MyDrive/Colab Notebooks/household objects.v2i.yolov8/data.yaml' model=yolov8l.pt epochs=100 lr0=0.01
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 243MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
from google.colab import files

# %%
files.download("/content/runs/detect/train/weights/best.pt")
